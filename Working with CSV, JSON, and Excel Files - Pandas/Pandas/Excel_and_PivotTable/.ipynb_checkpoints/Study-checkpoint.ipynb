# %%
import os

# %%
os.listdir()
# Out:
# ['Create Pivot Table.ipynb',
#  'Study.ipynb',
#  '.ipynb_checkpoints',
#  'sales-funnel(for_testing).xlsx']

# %%
import pandas as pd

# %%
df1 = pd.read_csv("../supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1[["Address","City"]]
# Out:
#            Address           City
# 0     3666 21st St  San Francisco
# 1   735 Dolores St  San Francisco
# 2      332 Hill St  San Francisco
# 3     3995 23rd St  San Francisco
# 4  1056 Sanchez St  San Francisco
# 5  551 Alvarado St  San Francisco

# %%
df1 = pd.read_csv("../supermarkets.csv", header=None) # We can specify header = None so all data in the table will be used as values, and not the first row as column names
df1
# Out:
#     0                1              2                 3        4            5  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#            6
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
# Assign Column Names
df1.columns = ["ID","Address","City","ZIP","Country","Name","Emplooyes"] # it has to be the same length as the columns
df1
# Out:
#    ID          Address           City               ZIP  Country         Name  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#    Emplooyes
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df1.set_index("ID")
# Out:
#             Address           City               ZIP  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#     Emplooyes
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df1
# Out:
#    ID          Address           City               ZIP  Country         Name  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#    Emplooyes
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df1_2 = df1.set_index("ID")
df1_2
# Out:
#             Address           City               ZIP  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#     Emplooyes
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df1.set_index("ID", inplace=True)
df1
# Out:
#             Address           City               ZIP  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#     Emplooyes
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df1.set_index("Address", inplace=True)
df1
# Out:
#                           City               ZIP  Country         Name  \
# Address
# Address                   City             State  Country         Name
# 3666 21st St     San Francisco          CA 94114      USA      Madeira
# 735 Dolores St   San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St      San Francisco  California 94114      USA  Super River
# 3995 23rd St     San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California      USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#                  Emplooyes
# Address
# Address          Employees
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df1.set_index("Name", inplace=True, drop=False)
df1
# Out:
#                       City               ZIP  Country         Name  Emplooyes
# Name
# Name                  City             State  Country         Name  Employees
# Madeira      San Francisco          CA 94114      USA      Madeira          8
# Bready Shop  San Francisco          CA 94119      USA  Bready Shop         15
# Super River  San Francisco  California 94114      USA  Super River         25
# Ben's Shop   San Francisco          CA 94114      USA   Ben's Shop         10
# Sanchez      San Francisco        California      USA      Sanchez         12
# Richvalley   San Francisco          CA 94114      USA   Richvalley         20

# %%
df1
# Out:
#                       City               ZIP  Country         Name  Emplooyes
# Name
# Name                  City             State  Country         Name  Employees
# Madeira      San Francisco          CA 94114      USA      Madeira          8
# Bready Shop  San Francisco          CA 94119      USA  Bready Shop         15
# Super River  San Francisco  California 94114      USA  Super River         25
# Ben's Shop   San Francisco          CA 94114      USA   Ben's Shop         10
# Sanchez      San Francisco        California      USA      Sanchez         12
# Richvalley   San Francisco          CA 94114      USA   Richvalley         20

# %%
df1.loc["Super River":"Ben's Shop","Country":"Emplooyes"]
# Out:
#             Country         Name Emplooyes
# Name
# Super River     USA  Super River        25
# Ben's Shop      USA   Ben's Shop        10

# %%
df1.loc["Sanchez","Country"]
# Out:
# 'USA'

# %%
df1.loc[:,"Country"]
# Out:
# Name
# Name           Country
# Madeira            USA
# Bready Shop        USA
# Super River        USA
# Ben's Shop         USA
# Sanchez            USA
# Richvalley         USA
# Name: Country, dtype: object

# %%
list(df1.loc[:,"Country"])
# Out:
# ['Country', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df1
# Out:
#                       City               ZIP  Country         Name  Emplooyes
# Name
# Name                  City             State  Country         Name  Employees
# Madeira      San Francisco          CA 94114      USA      Madeira          8
# Bready Shop  San Francisco          CA 94119      USA  Bready Shop         15
# Super River  San Francisco  California 94114      USA  Super River         25
# Ben's Shop   San Francisco          CA 94114      USA   Ben's Shop         10
# Sanchez      San Francisco        California      USA      Sanchez         12
# Richvalley   San Francisco          CA 94114      USA   Richvalley         20

# %%
df1.iloc[1:4,1:4]
# Out:
#                           ZIP Country         Name
# Name
# Madeira              CA 94114     USA      Madeira
# Bready Shop          CA 94119     USA  Bready Shop
# Super River  California 94114     USA  Super River

# %%
df1.iloc[:,1:4]
# Out:
#                           ZIP  Country         Name
# Name
# Name                    State  Country         Name
# Madeira              CA 94114      USA      Madeira
# Bready Shop          CA 94119      USA  Bready Shop
# Super River  California 94114      USA  Super River
# Ben's Shop           CA 94114      USA   Ben's Shop
# Sanchez            California      USA      Sanchez
# Richvalley           CA 94114      USA   Richvalley

# %%
df1.iloc[3,1:4]
# Out:
# ZIP        California 94114
# Country                 USA
# Name            Super River
# Name: Super River, dtype: object

# %%
df1
# Out:
#                       City               ZIP  Country         Name  Emplooyes
# Name
# Name                  City             State  Country         Name  Employees
# Madeira      San Francisco          CA 94114      USA      Madeira          8
# Bready Shop  San Francisco          CA 94119      USA  Bready Shop         15
# Super River  San Francisco  California 94114      USA  Super River         25
# Ben's Shop   San Francisco          CA 94114      USA   Ben's Shop         10
# Sanchez      San Francisco        California      USA      Sanchez         12
# Richvalley   San Francisco          CA 94114      USA   Richvalley         20

# %%
df1.drop("City", 1) # 1 means we want to delete columns. 0 means we want to delete rows.
# also, .drop method is not an in-place operation, so it won't affect the current object.
# Out:
#                           ZIP  Country         Name  Emplooyes
# Name
# Name                    State  Country         Name  Employees
# Madeira              CA 94114      USA      Madeira          8
# Bready Shop          CA 94119      USA  Bready Shop         15
# Super River  California 94114      USA  Super River         25
# Ben's Shop           CA 94114      USA   Ben's Shop         10
# Sanchez            California      USA      Sanchez         12
# Richvalley           CA 94114      USA   Richvalley         20

# %%
df1.drop("Madeira", 0)
# Out:
#                       City               ZIP  Country         Name  Emplooyes
# Name
# Name                  City             State  Country         Name  Employees
# Bready Shop  San Francisco          CA 94119      USA  Bready Shop         15
# Super River  San Francisco  California 94114      USA  Super River         25
# Ben's Shop   San Francisco          CA 94114      USA   Ben's Shop         10
# Sanchez      San Francisco        California      USA      Sanchez         12
# Richvalley   San Francisco          CA 94114      USA   Richvalley         20

# %%
df1
# Out:
#                       City               ZIP  Country         Name  Emplooyes
# Name
# Name                  City             State  Country         Name  Employees
# Madeira      San Francisco          CA 94114      USA      Madeira          8
# Bready Shop  San Francisco          CA 94119      USA  Bready Shop         15
# Super River  San Francisco  California 94114      USA  Super River         25
# Ben's Shop   San Francisco          CA 94114      USA   Ben's Shop         10
# Sanchez      San Francisco        California      USA      Sanchez         12
# Richvalley   San Francisco          CA 94114      USA   Richvalley         20

# %%
df1.index[0:3] # will print from first row, up to, but not including the 3rd one.
# Out:
# Index(['Name', 'Madeira', 'Bready Shop'], dtype='object', name='Name')

# %%
# We can also use .index method along with .drop()
df1.drop(df1.index[0:3],0)
# Out:
#                       City               ZIP Country         Name Emplooyes
# Name
# Super River  San Francisco  California 94114     USA  Super River        25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop        10
# Sanchez      San Francisco        California     USA      Sanchez        12
# Richvalley   San Francisco          CA 94114     USA   Richvalley        20

# %%
df1
# Out:
#                       City               ZIP  Country         Name  Emplooyes
# Name
# Name                  City             State  Country         Name  Employees
# Madeira      San Francisco          CA 94114      USA      Madeira          8
# Bready Shop  San Francisco          CA 94119      USA  Bready Shop         15
# Super River  San Francisco  California 94114      USA  Super River         25
# Ben's Shop   San Francisco          CA 94114      USA   Ben's Shop         10
# Sanchez      San Francisco        California      USA      Sanchez         12
# Richvalley   San Francisco          CA 94114      USA   Richvalley         20

# %%
df1.columns[0:3] # starts from City, because "name" is the index for the rows, not columns.
# Out:
# Index(['City', 'ZIP', 'Country'], dtype='object')

# %%
df1.drop(df1.columns[0:3],1)
# Out:
#                     Name  Emplooyes
# Name
# Name                Name  Employees
# Madeira          Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df1.index
# Out:
# Index(['Name', 'Madeira', 'Bready Shop', 'Super River', 'Ben's Shop',
#        'Sanchez', 'Richvalley'],
#       dtype='object', name='Name')

# %%
df1.columns
# Out:
# Index(['City', 'ZIP', 'Country', 'Name', 'Emplooyes'], dtype='object')

# %%
df1
# Out:
#                       City               ZIP  Country         Name  Emplooyes
# Name
# Name                  City             State  Country         Name  Employees
# Madeira      San Francisco          CA 94114      USA      Madeira          8
# Bready Shop  San Francisco          CA 94119      USA  Bready Shop         15
# Super River  San Francisco  California 94114      USA  Super River         25
# Ben's Shop   San Francisco          CA 94114      USA   Ben's Shop         10
# Sanchez      San Francisco        California      USA      Sanchez         12
# Richvalley   San Francisco          CA 94114      USA   Richvalley         20

# %%
df1["Continent"]=["North America"] # Returns an error because we need to pass the exact number of rows
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-b156bbfb1071> in <module>
# ----> 1 df1["Continent"]=["North America"]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# ...

# %%
df1.shape # tuple with number of rows and columns
# Out:
# (7, 5)

# %%
df1["Continent"]=df1.shape[0]*["North America"]

# %%
df1
# Out:
#                       City               ZIP  Country         Name  Emplooyes  \
# Name
# Name                  City             State  Country         Name  Employees
# Madeira      San Francisco          CA 94114      USA      Madeira          8
# Bready Shop  San Francisco          CA 94119      USA  Bready Shop         15
# Super River  San Francisco  California 94114      USA  Super River         25
# Ben's Shop   San Francisco          CA 94114      USA   Ben's Shop         10
# Sanchez      San Francisco        California      USA      Sanchez         12
# Richvalley   San Francisco          CA 94114      USA   Richvalley         20
#
#                  Continent
# Name
# Name         North America
# Madeira      North America
# Bready Shop  North America
# Super River  North America
# Ben's Shop   North America
# Sanchez      North America
# Richvalley   North America

# %%
df1["Continent"] = df1["Country"] + ", " + "North America" # Changing the values for "Continent" Column.

# %%
df1
# Out:
#                       City               ZIP  Country         Name  Emplooyes  \
# Name
# Name                  City             State  Country         Name  Employees
# Madeira      San Francisco          CA 94114      USA      Madeira          8
# Bready Shop  San Francisco          CA 94119      USA  Bready Shop         15
# Super River  San Francisco  California 94114      USA  Super River         25
# Ben's Shop   San Francisco          CA 94114      USA   Ben's Shop         10
# Sanchez      San Francisco        California      USA      Sanchez         12
# Richvalley   San Francisco          CA 94114      USA   Richvalley         20
#
#                           Continent
# Name
# Name         Country, North America
# Madeira          USA, North America
# Bready Shop      USA, North America
# Super River      USA, North America
# Ben's Shop       USA, North America
# Sanchez          USA, North America
# Richvalley       USA, North America

# %%
# Adding a new row is a bit tricky:

# %%
df1_t=df1.T # .T method transposes your dataframe

# %%
df1_t
# Out:
# Name                         Name             Madeira         Bready Shop  \
# City                         City       San Francisco       San Francisco
# ZIP                         State            CA 94114            CA 94119
# Country                   Country                 USA                 USA
# Name                         Name             Madeira         Bready Shop
# Emplooyes               Employees                   8                  15
# Continent  Country, North America  USA, North America  USA, North America
#
# Name              Super River          Ben's Shop             Sanchez  \
# City            San Francisco       San Francisco       San Francisco
# ZIP          California 94114            CA 94114          California
# Country                   USA                 USA                 USA
# Name              Super River          Ben's Shop             Sanchez
# Emplooyes                  25                  10                  12
# ...

# %%
df1_t["My Address"]=["My City", "My ZIP", "My Country", "My Name", 10, "My Continent"]

# %%
df1 = df1_t.T

# %%
df1
# Out:
#                       City               ZIP     Country         Name  \
# Name
# Name                  City             State     Country         Name
# Madeira      San Francisco          CA 94114         USA      Madeira
# Bready Shop  San Francisco          CA 94119         USA  Bready Shop
# Super River  San Francisco  California 94114         USA  Super River
# Ben's Shop   San Francisco          CA 94114         USA   Ben's Shop
# Sanchez      San Francisco        California         USA      Sanchez
# Richvalley   San Francisco          CA 94114         USA   Richvalley
# My Address         My City            My ZIP  My Country      My Name
#
#              Emplooyes               Continent
# Name
# Name         Employees  Country, North America
# Madeira              8      USA, North America
# Bready Shop         15      USA, North America
# Super River         25      USA, North America
# Ben's Shop          10      USA, North America
# ...

# %%
# We can also modify a row in the same way as above, example:
# df1_t=df1.T
# df1_t["Ben's Shop"]=[“Another city", “Another ZIP", “Another Country", “Another Name", 11, “Another Continent”]
# df1=df1_t.T

# %%
df2 = pd.read_excel("../supermarkets.xlsx", sheet_name=0)
df2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3 = pd.read_csv("../supermarkets-commas.txt")
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4 = pd.read_csv("../supermarkets-semi-colons.txt", sep=";")
df4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

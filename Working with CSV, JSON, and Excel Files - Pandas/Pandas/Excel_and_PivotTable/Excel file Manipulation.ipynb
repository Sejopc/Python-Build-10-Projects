# %%
import pandas as pd
import numpy as py
import os

# %%
os.listdir()
# Out:
# ['Excel file Manipulation.ipynb',
#  '~$sales-funnel(for_testing).xlsx',
#  'Geocoding Addresses with Pandas and Geopy - Study.ipynb',
#  'Create Pivot Table.ipynb',
#  'Study.ipynb',
#  '.ipynb_checkpoints',
#  'sales-funnel(for_testing).xlsx']

# %%
df = pd.read_excel("sales-funnel(for_testing).xlsx", index_col=0)
df
# Out:
#                                  Name            Rep        Manager  \
# Account
# 714466                Trantow-Barrows   Craig Booker   Debra Henley
# 714466                Trantow-Barrows   Craig Booker   Debra Henley
# 714466                Trantow-Barrows   Craig Booker   Debra Henley
# 737550   Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 146832                   Kiehn-Spinka  Daniel Hilton   Debra Henley
# 218895                      Kulas Inc  Daniel Hilton   Debra Henley
# 218895                      Kulas Inc  Daniel Hilton   Debra Henley
# 412290                  Jerde-Hilpert     John Smith   Debra Henley
# 740150                     Barton LLC     John Smith   Debra Henley
# 141962                     Herman LLC    Cedric Moss  Fred Anderson
# 163416                    Purdy-Kunde    Cedric Moss  Fred Anderson
# 239344                     Stokes LLC    Cedric Moss  Fred Anderson
# 239344                     Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
df = df.sort_values(by = ['Account','Name'], ascending = [False, True])
df
# Out:
#                                  Name            Rep        Manager  \
# Account
# 740150                     Barton LLC     John Smith   Debra Henley
# 737550   Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 729833                      Koepp Ltd     Wendy Yule  Fred Anderson
# 729833                      Koepp Ltd     Wendy Yule  Fred Anderson
# 714466                Trantow-Barrows   Craig Booker   Debra Henley
# 714466                Trantow-Barrows   Craig Booker   Debra Henley
# 714466                Trantow-Barrows   Craig Booker   Debra Henley
# 688981                    Keeling LLC     Wendy Yule  Fred Anderson
# 412290                  Jerde-Hilpert     John Smith   Debra Henley
# 307599    Kassulke, Ondricka and Metz     Wendy Yule  Fred Anderson
# 239344                     Stokes LLC    Cedric Moss  Fred Anderson
# 239344                     Stokes LLC    Cedric Moss  Fred Anderson
# 218895                      Kulas Inc  Daniel Hilton   Debra Henley
# ...

# %%
df.describe()
# Out:
#         Quantity          Price
# count  17.000000      17.000000
# mean    1.764706   30705.882353
# std     1.032558   28444.605609
# min     1.000000    5000.000000
# 25%     1.000000    7000.000000
# 50%     2.000000   30000.000000
# 75%     2.000000   40000.000000
# max     5.000000  100000.000000
